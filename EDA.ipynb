# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('model_df.csv')
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  12.309982         3       1.00     7.073270      5650     1.0     0
# 1  13.195614         3       2.25     7.851661      7242     2.0     0
# 2  12.100712         2       1.00     6.646391     10000     1.0     0
# 3  13.311329         4       3.00     7.580700      5000     1.0     0
# 4  13.142166         3       2.00     7.426549      8080     1.0     0
#
#    condition  grade  sqft_above  ...  distance_from_nearest_hotspot  \
# 0          3      7        1180  ...                       2.662882
# 1          3      7        2170  ...                       2.288785
# 2          3      6         770  ...                       2.311032
# 3          5      7        1050  ...                       2.291486
# 4          3      8        1680  ...                       1.540106
#
#    year_last_renovated  time_since_renovated  total_rooms  condition_grade  \
# ...

# %%
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
}
# Out:
#   File "<ipython-input-11-8f074a234b92>", line 1
#     IPython.OutputArea.prototype._should_scroll = function(lines) {
#                                                                   ^
# SyntaxError: invalid syntax

# %%
for col in df.columns:
    sns.lmplot(x= col, y = 'price_o', data = df, line_kws={'color': 'red'})
    plt.show()

# %%
 sns.lmplot(x= 'condition_grade', y = 'price_o', data = df)

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr().abs()[np.abs(df.corr()>.4)], center=0, annot =True);
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show() # ta-da!

# %%
df['sqft_lot'].describe()
# Out:
# count     19682.000000
# mean      10259.867544
# std       12818.544832
# min         520.000000
# 25%        5000.000000
# 50%        7388.000000
# 75%       10000.000000
# max      138085.000000
# Name: sqft_lot, dtype: float64

# %%
df['sqft_living_o'] = np.exp(df['sqft_living'])

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  12.309982         3       1.00     7.073270      5650     1.0     0
# 1  13.195614         3       2.25     7.851661      7242     2.0     0
# 2  12.100712         2       1.00     6.646391     10000     1.0     0
# 3  13.311329         4       3.00     7.580700      5000     1.0     0
# 4  13.142166         3       2.00     7.426549      8080     1.0     0
#
#    condition  grade  sqft_above  ...  year_last_renovated  \
# 0          3      7        1180  ...               1955.0
# 1          3      7        2170  ...               1991.0
# 2          3      6         770  ...               1933.0
# 3          5      7        1050  ...               1965.0
# 4          3      8        1680  ...               1987.0
#
#    time_since_renovated  total_rooms  condition_grade  sqft_total   price_o  \
# 0                  60.0         4.00               10    7.073270  221900.0
# ...

# %%
df['sqft_living_o'].describe()
# Out:
# count    19682.000000
# mean      1982.807337
# std        743.676912
# min        390.000000
# 25%       1420.000000
# 50%       1870.000000
# 75%       2440.000000
# max       4720.000000
# Name: sqft_living_o, dtype: float64
