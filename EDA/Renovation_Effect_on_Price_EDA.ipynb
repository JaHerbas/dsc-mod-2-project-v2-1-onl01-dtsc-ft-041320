# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('../model_df.csv')
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  12.309982         3       1.00     7.073270      5650     1.0     0
# 1  13.195614         3       2.25     7.851661      7242     2.0     0
# 2  12.100712         2       1.00     6.646391     10000     1.0     0
# 3  13.311329         4       3.00     7.580700      5000     1.0     0
# 4  13.142166         3       2.00     7.426549      8080     1.0     0
#
#    condition  grade  sqft_above  ...  distance_from_nearest_hotspot  \
# 0          3      7        1180  ...                       2.662882
# 1          3      7        2170  ...                       2.288785
# 2          3      6         770  ...                       2.311032
# 3          5      7        1050  ...                       2.291486
# 4          3      8        1680  ...                       1.540106
#
#    year_last_renovated  time_since_renovated  total_rooms  condition_grade  \
# ...

# %%
sns.set()
sns.lmplot(x= 'time_since_renovated', y = 'price_o', data = df, line_kws={'color': 'red'})

# %% [markdown]
# While not a strong indicator, it does appear that recency of renovation does seem to effect sell price. We can see the the longer the house goes without renovation the price does make a gradual decline.
